# %% [markdown]
# <a href="https://colab.research.google.com/github/Aliriio/MetNumUN2024I/blob/main/Quiz9.5/Quiz___SymPy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Solve the using *LUsolve* from sympy the   2 $\times$ 2 system $Ax=b$, inside the function *LUsolve_2_by_2_lin_sys* with
#
# $$A = \left[
#   \begin{array}{cc}
# e & i\\
#  \sqrt{2}& \pi
# \end{array}
# \right]
# $$
#
# $$b  = \left[
#   \begin{array}{c}
# \sqrt{3} \\
# 1
# \end{array}
# \right]
# $$

# %%
from sympy import *
init_printing()

def LUsolve_2_by_2_lin_sys():
    A = Matrix([[E, I],
                [sqrt(2), pi]])

    b = Matrix(2, 1, [sqrt(3), 1])

    # Resolver el sistema de ecuaciones Ax = b
    x = A.LUsolve(b)

    return x

LUsolve_2_by_2_lin_sys()

# %% [markdown]
# # 2. Solve the using *solve* from sympy the   2 $\times$ 2 system $Ax=b$, inside the function *solve_2_by_2_lin_sys* with
#
# $$A = \left[
#   \begin{array}{cc}
# e & i\\
#  \sqrt{2}& \pi
# \end{array}
# \right]
# $$
#
# $$b  = \left[
#   \begin{array}{c}
# \sqrt{3} \\
# 1
# \end{array}
# \right]
# $$

# %%
from sympy import *
init_printing()

def solve_2_by_2_lin_sys():

  A = Matrix([[E,I],
            [sqrt(2),pi]])
  b = Matrix(2,1,[sqrt(3),1])

  sol =

  return sol
